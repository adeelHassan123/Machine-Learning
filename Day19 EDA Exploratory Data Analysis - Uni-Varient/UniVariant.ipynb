# %% [markdown]
# # Day 19: Exploratory Data Analysis (EDA) - Univariate
#
# This folder focuses on univariate EDA, which means analyzing one variable at a time to understand its distribution, summary statistics, and potential issues.
#
# ## Key Concepts Covered
#
# - Loading Data:
#   - Using pandas to read the dataset (train.csv).
# - Data Overview:
#   - Viewing the structure and types of data using df.info().
# - Checking for Missing Values:
#   - Using df.isnull().sum() to find missing data.
# - Descriptive Statistics:
#   - Using df.describe() to get statistics like mean, median, min, max, etc.
# - Finding Duplicates:
#   - Using df.duplicated().sum() to check for duplicate rows.
# - Correlation Analysis:
#   - Calculating correlations between numerical columns to see how they relate.
#
# ## Libraries Used
#
# - pandas: For all data analysis tasks.
#
# ## Why This is Important
#
# Univariate EDA is the first step in understanding your data. It helps you spot problems, understand distributions, and prepare for deeper analysis.
#
# This folder is a practical guide to the basics of EDA in Python!

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\usman-pc\anaconda3\envs\my_environment\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
df = pd.read_csv("train.csv")
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# # CATEGORIALCAL DATA

# %% [markdown]
# <H3>A. CountPLot</H3>

# %%
sns.countplot(x='Survived', data=df)
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=df)
#calculate the number of passengers in each class and fare of each class
df['Pclass'].value_counts()
#calculate the number of passengers in each class and fare of each class
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# <h3>b. PieCHart
# </h3>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct ='%.2f')
plt.title('Passenger Class Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Class Distribution')

# %%
df['Sex'].value_counts().plot(kind='pie',autopct ='%.2f')
plt.title('Sex Distribution')
# Out:
# Text(0.5, 1.0, 'Sex Distribution')

# %% [markdown]
# # 2. NUMERICAL DATA

# %% [markdown]
# <h3>a. HISTO--GRAMMMM</H3>

# %%
plt.hist(df['Age'])
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
df['SibSp'].value_counts().plot(kind='bar')
plt.xlabel('Number of Siblings/Spouses')
plt.ylabel('Number of Passengers')
plt.title('Siblings/Spouses Distribution')
# Out:
# Text(0.5, 1.0, 'Siblings/Spouses Distribution')

# %% [markdown]
# <h3>DIST--PLOTTT</H3>

# %%
#kde = Kernel Density Estimate 
# kde is used to visualize the distribution of a variable
#kernel is a function that is used to smooth the distribution
sns.displot(df['Pclass'], kde=True)
plt.title('Fare Distribution')
# Out:
# Text(0.5, 1.0, 'Fare Distribution')
